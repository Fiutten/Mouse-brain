# %% [markdown]
# # Build a synthetic engineering connectome
# Demonstrates contracts and graph construction. It does not demonstrate biological validity.

# %%
from mousebrainbench.connectivity.synthetic import generate_synthetic_connectivity
from mousebrainbench.connectivity.graph_builder import build_directed_graph
regions, connectivity = generate_synthetic_connectivity(50, seed=17)
graph = build_directed_graph(regions, connectivity)
graph.number_of_nodes(), graph.number_of_edges(), connectivity.metadata
