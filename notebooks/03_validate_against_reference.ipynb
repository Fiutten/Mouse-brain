# %% [markdown]
# # Validation boundary
# Phase 1 has no empirical reference dataset. This notebook intentionally stops at loading generated metrics; claiming empirical validation here would be scientifically incorrect.

# %%
import json
from pathlib import Path
runs = sorted(Path('../outputs').glob('phase1-*'))
json.loads((runs[-1] / 'metrics.json').read_text()) if runs else 'Run notebook 02 first.'
