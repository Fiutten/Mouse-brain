# %% [markdown]
# # Run a mesoscopic simulation
# Demonstrates the tested runner on synthetic connectivity. Parameters are not fitted to mouse data.

# %%
from mousebrainbench.config import load_config
from mousebrainbench.cli import execute
run_dir = execute(load_config('../configs/default.yaml'))
run_dir
